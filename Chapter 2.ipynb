# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
cd /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Bayogos
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Bayogos

# %%
# !ls
# Out:
# 'Chapter 2.ipynb'				   Phyton101_Bayogos.ipynb
# 'Copy of (IS110)Using_Git on Google Colab.ipynb'   PythonEnvi_Bayogos
# 'IS110_repo_Bayogos (1)'			   Untitled0.ipynb

# %% [markdown]
# Exercise **1**

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.
# ```
# Enter your name: Chuck
# Hello Chuck
# ```
# [PEW] E2.2

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Edward Bayogos
# Hello Edward Bayogos

# %% [markdown]
# Exercise 2

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```
#
# [PEW] E2.3

# %%
hours_str = input('Enter Hours: ')
rate_str = input('Enter Rate: ')

hours = float(hours_str)
rate = float(rate_str)

gross_pay = hours * rate

print('Pay:', gross_pay)
# Out:
# Enter Hours: 8
# Enter Rate: 900
# Pay: 7200.0

# %% [markdown]
# Exercise 3

# %%
width = 17
height = 12.0

print('width//2:', width // 2, type(width // 2))
print('width/2.0:', width / 2.0, type(width / 2.0))
print('height/3:', height / 3, type(height / 3))
print('1 + 2 * 5:', 1 + 2 * 5, type(1 + 2 * 5))
# Out:
# width//2: 8 <class 'int'>
# width/2.0: 8.5 <class 'float'>
# height/3: 4.0 <class 'float'>
# 1 + 2 * 5: 11 <class 'int'>

# %% [markdown]
# Exercise 4

# %%
# Exercise 4
# Write a program that uses input to prompt a user for a number and then outputs the square of the number
# Example:
# Enter a number: 3
# The square of 3 is 9

num_str = input("Enter a number: ")
try:
    num = float(num_str)
    square = num ** 2
    print(f"The square of {num_str} is {square}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
# Out:
# Enter a number: 13
# The square of 13 is 169.0

# %% [markdown]
# **CHALLENGE**

# %%
celsius_str = input("Enter Celsius temperature: ")
celsius = float(celsius_str)
fahrenheit = (celsius * 9/5) + 32
print("Fahrenheit temperature:", fahrenheit)
# Out:
# Enter Celsius temperature: 39
# Fahrenheit temperature: 102.2
