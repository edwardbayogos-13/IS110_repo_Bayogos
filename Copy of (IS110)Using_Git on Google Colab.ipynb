# %% [markdown]
# ### Using Git in Google Colab
#
# You need to configure the user.name, email.address, and the token

# %%
# !git config --global user.name 'Edward Bayogos'
# !git config --global user.email 'edward.bayogos@students.isatu.edu.ph'
#!git config --global user.password = 'xxx your TOKEN xxx' #password should be the token

# %% [markdown]
# ### Initializing the github repo
#
# - Do change the following into your own username, token on which you have saved previously
#
# - https://{AetherYang13}:{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}@github.com/{AetherYang13}/{https://github.com/edwardbayogos-13/IS110_repo_Bayogos}.git

# %%
# !git clone https://edwardbayogos-13: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@github.com/edwardbayogos-13/IS110_repo_Bayogos.git
# Out:
# Cloning into 'IS110_repo_Bayogos'...
# warning: You appear to have cloned an empty repository.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# changing the working directory
# %cd /content/drive/MyDrive/ColabNotebooks
# Out:
# /content/drive/MyDrive/ColabNotebooks

# %%
# moving the repo to the working directory
# !mv "/content/IS110_repo_Bayogos" "/content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos"
# Out:
# mv: cannot stat '/content/IS110_repo_Bayogos': No such file or directory

# %%
ls
# Out:
# newupload.gdoc

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos

# %%
# copy files to the working directory

# !cp "/content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos/newupload.txt" "/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Bayogos/IS110_repo_Bayogos"
#!cp "/content/drive/MyDrive/ColabNotebooks/Python_Fundamentals/00 Jupyter Notebooks Tutorial (Workbook).ipynb" "/content/AppDev_Jamile/worksheet#1"

# %% [markdown]
# #### Changing the directory
#
# **cd** is changing a directory
# In google colab, use of *%* indicates that it you will be using a terminal.

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos

# %% [markdown]
# #### Using PWD
# - this writes the current path of the working directory

# %%
# !pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos

# %% [markdown]
# ### Sample file to be uploaded to git using **touch**

# %%
# !touch world.py #make sure that the path points of your repo

#check the file if it is added in the repo just double click the folder
print('Done')
# Out:
# Done

# %% [markdown]
# #### Using ls
# - listing of the content of the current directory

# %%
# %ls
# Out:
# newupload.txt  world.py

# %% [markdown]
# ### Initializing the git
# Initializing the Git repository in the current directory

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos/.git/

# %% [markdown]
# ### Adding a file
# + adds the file, preparing for commitment

# %%
# !git add newupload.txt

# %%
### Another Way to git add
# !git add . - means that the whole image h

# %%
# !git status
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	world.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ### Commiting your first git
#
# Commitment message should have a meaning such as "first commit", "updated commit"

# %%
# !git commit -m 'new commit'
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	world.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git status
# Out:
# On branch main
# Your branch is based on 'origin/main', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	world.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ### Changing the Branch
#
# + Renames the default branch from 'master' to 'main'.

# %%
# !git branch -M main

# %% [markdown]
# #Push the committed file

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 227 bytes | 22.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/edwardbayogos-13/IS110_repo_Bayogos.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !cp "/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Bayogos/Phyton101_Bayogos" "/content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos"
# Out:
# cp: cannot stat '/content/drive/MyDrive/ColabNotebooks/IS110_BPerformance_Bayogos/Phyton101_Bayogos': No such file or directory

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ColabNotebooks/IS110_repo_Bayogos/.git/

# %%
# !get add "IS110_BPerformance_Bayogos_Phyton1"
